# %%
import orderbook_lib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

plt.style.use('https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-light.mplstyle')

# %%
orderbook_lib.from_file("../data/OrderLog_20200908_OFZ.csv", "SU26205RMFS3", 0.001)
# Out:
# SU26226RMFS9
# SU26205RMFS3
# SU26209RMFS5
# SU26212RMFS9
# SU29007RMFS0
# SU29014RMFS6
# SU46012RMFS9
# SU26233RMFS5
# SU26223RMFS6
# SU52002RMFS1
# SU29008RMFS8
# SU46020RMFS2
# SU52001RMFS3
# SU26220RMFS2
# SU24021RMFS6
# SU26211RMFS1
# SU26230RMFS1
# SU26228RMFS5
# SU26224RMFS4
# SU46023RMFS6
# SU26225RMFS1
# SU25083RMFS5
# SU26217RMFS8
# SU26222RMFS8
# SU26218RMFS6
# SU29010RMFS4
# SU26219RMFS4
# SU26207RMFS9
# SU46022RMFS8
# SU26215RMFS2
# SU29006RMFS2
# SU26231RMFS9
# SU26227RMFS7
# SU26234RMFS3
# SU29009RMFS6
# SU26232RMFS7
# SU25084RMFS3
# SU46018RMFS6
# SU26221RMFS0
# SU46011RMFS1
# SU24020RMFS8
# SU29012RMFS0
# SU26229RMFS3

# %%
with open("SU26205RMFS3_l2_bid.txt") as file_ask:
    lines = file_ask.read().splitlines()
    l2_bid_orderbook = pd.read_json(lines[-1], orient='values')
    l2_bid_orderbook = l2_bid_orderbook.iloc[:-1]


l2_bid_orderbook.columns = ["price", "value"]
l2_bid_orderbook.set_index("price", inplace=True)

# %%
with open("SU26205RMFS3_l2_ask.txt") as file_ask:
    lines = file_ask.read().splitlines()
    l2_ask_orderbook = pd.read_json(lines[-1], orient='values')
    l2_ask_orderbook = l2_ask_orderbook.iloc[:-1]

l2_ask_orderbook.columns = ["price", "value"]
l2_ask_orderbook.set_index("price", inplace=True)
# Out:
# /var/folders/f2/0t72_0jx48526fr5cl7zyc3h0000gn/T/ipykernel_98813/3112827225.py:3: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   l2_ask_orderbook = pd.read_json(lines[-1], orient='values')

# %%
l2_ask_orderbook['value_cumsum'] = l2_ask_orderbook['value'].cumsum()
l2_bid_orderbook['value_cumsum'] = l2_bid_orderbook['value'].cumsum()

# %%
l2_bid_orderbook
# Out:
#           value  value_cumsum
# price
# 102.090     589           589
# 102.085   12196         12785
# 102.080  200006        212791
# 102.079      10        212801
# 102.067     146        212947
# 102.060     477        213424
# 102.058      98        213522
# 102.056      69        213591
# 102.055       5        213596
# 102.050      43        213639
# 102.040      23        213662
# 102.035       1        213663
# 102.033      30        213693
# 102.032      71        213764
# 102.031       7        213771
# 102.030    1005        214776
# 102.025      11        214787
# 102.022     103        214890
# 102.021      10        214900
# 102.020      26        214926
# 102.010      26        214952
# 102.006     252        215204
# 102.005     500        215704
# 102.002     100        215804
# 102.000   45133        260937
# 101.990       1        260938
# 101.946       6        260944
# 101.900      13        260957
# 101.890       1        260958
# 101.860       2        260960
# 101.807      21        260981
# 101.806      50        261031
# 101.790       1        261032
# 101.759      50        261082
# 101.722      50        261132
# 101.721      50        261182
# 101.710      20        261202
# 101.690       1        261203
# 101.687      50        261253
# 101.649      50        261303
# 101.610      50        261353
# 101.518      11        261364
# 101.502    2150        263514
# 101.100      10        263524
# 101.008      10        263534
# 101.000      11        263545
# 100.832     100        263645
# 100.623     380        264025
# 100.622     200        264225
# 100.599      24        264249
# 100.560       1        264250
# 100.500       3        264253
# 100.483     100        264353
# 100.222   10000        274353
# 100.209     200        274553
# 100.100      20        274573
# 100.006     100        274673
# 100.001       2        274675
# 100.000    6699        281374
# 99.885      101        281475

# %%
l2_ask_orderbook
# Out:
#          value  value_cumsum
# price
# 102.140     23            23
# 102.145     75            98
# 102.150    100           198
# 102.179     50           248
# 102.180    106           354
# 102.190      4           358
# 102.198    147           505
# 102.200   6470          6975
# 102.202   2276          9251
# 102.216     20          9271
# 102.217     20          9291
# 102.220    200          9491
# 102.238     35          9526
# 102.247     60          9586
# 102.248    180          9766
# 102.250  45000         54766
# 102.270      4         54770
# 102.290   2649         57419
# 102.297     30         57449
# 102.299   2288         59737
# 102.300    711         60448
# 102.320    900         61348
# 102.339     30         61378
# 102.347     30         61408
# 102.400    422         61830
# 102.437     30         61860
# 102.447     30         61890
# 102.500   2882         64772
# 102.550    146         64918
# 102.650  11912         76830
# 102.700   4571         81401
# 102.800     13         81414
# 102.900     10         81424
# 102.993    440         81864
# 103.498    451         82315
# 104.091   1806         84121

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6), sharey=True)
l2_bid_orderbook["value_cumsum"].plot(ax=axes[0],kind = "line", ylabel = "volume", color = "Green")
l2_ask_orderbook["value_cumsum"].plot(ax=axes[1], kind = "line", color = "Red")
# Out:
# <Axes: xlabel='price'>
